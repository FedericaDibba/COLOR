# %% [markdown]
# # Graph Coloring with Physics-Inspired Graph Neural Networks(SAGE)

# %%
import torch
import torchvision
print(torch.__version__)
print(torchvision.__version__)
import os.path
# Out:
# 2.4.1+cu121
# 0.19.1+cu121

# %%
import random
import torch
import warnings
import numpy as np
import networkx as nx
import os
import torch.nn as nn
import torch.nn.functional as F


from time import time

# %%
from google.colab import drive
drive.mount('/content/drive',force_remount=True)
# Out:
# Mounted at /content/drive

# %%
try:
    import torch_geometric
except ImportError:
    # !pip install torch_geometric
    import torch_geometric

# %%
from torch_geometric.data import Data
from torch_geometric.nn import SAGEConv, GCNConv
from itertools import chain

# %%
# define device to use (cpu/gpu)
if torch.cuda.is_available():
  print('# of GPUs available: ', torch.cuda.device_count())
  print('First GPU type: ',torch.cuda.get_device_name(0))
device = ('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Computation device: {device}\n")
# Out:
# Computation device: cpu

# %%
SEED_VALUE = 0           #lo richiamo anche sotto per get_gnn
random.seed(SEED_VALUE)        # seed python RNG
np.random.seed(SEED_VALUE)     # seed global NumPy RNG
torch.manual_seed(SEED_VALUE)  # seed torch RNG

# Set GPU/CPU
TORCH_DEVICE = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
TORCH_DTYPE = torch.float32
print(f'Will use device: {TORCH_DEVICE}, torch dtype: {TORCH_DTYPE}')
# Out:
# Will use device: cpu, torch dtype: torch.float32

# %%
cd /content/drive/MyDrive/FEDECOLOR
# Out:
# /content/drive/MyDrive/FEDECOLOR

# %%
ls
# Out:
# data/                              minimal_utils_vecchiaprova4.py
# gc_example.ipynb                   minimal_utils_vecchiaprova5_primaAttivazioneAparte.py
# gc_example_prova1.ipynb            minimal_utils_vecchiaprova.py
# GCN_best_model_coloring_5X5.pth    __pycache__/
# instances.tar                      requirements.txt
# minimal_utils.py                   SAGE_best_model_coloring_5X5.pth
# minimal_utils_vecchiaprova2.ipynb  SAGE_best_model_coloring_7X7
# minimal_utils_vecchiaprova3.py     SAGE_best_model_coloring_7X7.pth

# %%
# Known chromatic numbers for specified problems (from references)
chromatic_numbers = {
    # COLOR graphs
    'jean.col': 10,
    'anna.col': 11,
    'huck.col': 11,
    'david.col': 11,
    'homer.col': 13,
    'myciel5.col': 6,
    'myciel6.col': 7,
    'queen5_5.col': 5,
    'queen6_6.col': 7,
    'queen7_7.col': 7,
    'queen8_8.col': 9,
    'queen9_9.col': 10,
    'queen8_12.col': 12,
    'queen11_11.col': 11,
    'queen13_13.col': 13,
    # Citations graphs
    'cora.cites': 5,
    'citeseer.cites': 6,
    'pubmed.cites': 8
}

# %%
#FACCIO FUNZIONE CHE SALVA BEST MODELLO COSI NON DEVO CAMBIARE SOTTO IL NOME DEL FILE
def save_model(model,path, best_cost, best_loss, epoch):
    torch.save(model.state_dict(), path)                    #aggiunto stasera
    print(f'Model saved with best_cost: {best_cost:.4f}  and best_loss(soft loss): {best_loss:.4f} at the epoch: {epoch}')

# %%
#funzione per cambiare il seme nel train
def set_seed(seed):
    """
    Sets random seeds for training.

    :param seed: Integer used for seed.
    :type seed: int
    """
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed_all(seed)

# %%
def get_adjacency_matrix(nx_graph, torch_device, torch_dtype):
    """
    Pre-load adjacency matrix, map to torch device

    :param nx_graph: Graph object to pull adjacency matrix for
    :type nx_graph: networkx.OrderedGraph   per me cambiato con DiGraph/Graph
    :param torch_device: Compute device to map computations onto (CPU vs GPU)
    :type torch_dtype: str
    :param torch_dtype: Specification of pytorch datatype to use for matrix
    :type torch_dtype: str
    :return: Adjacency matrix for provided graph
    :rtype: torch.tensor
    """

    adj = nx.linalg.graphmatrix.adjacency_matrix(nx_graph).todense()
    adj_ = torch.tensor(adj).type(torch_dtype).to(torch_device)

    return adj_

# %%
def parse_line(file_line, node_offset):
    """
    Helper function to parse lines out of COLOR files - skips first character, which
    will be an "e" to denote an edge definition, and returns node0, node1 that define
    the edge in the line.

    :param file_line: Line to be parsed
    :type file_line: str
    :param node_offset: How much to add to account for file numbering (i.e. offset by 1)
    :type node_offset: int
    :return: Set of nodes connected by edge defined in the line (i.e. node_from, node_to)
    :rtype: int, int
    """

    x, y = file_line.split(' ')[1:]  # skip first character - specifies each line is an edge definition
    x, y = int(x)+node_offset, int(y)+node_offset  # nodes in file are 1-indexed, whereas python is 0-indexed (NON PENSO SIA QUESTO IL PROBLEMA)
    return x, y

# %%
def build_graph_from_color_file(fname, node_offset=-1, parent_fpath=''):               #sta tutto qua come creo grafico
    """
    Load problem definition (graph) from COLOR file (e.g. *.col).

    :param fname: Filename of COLOR file
    :type fname: str
    :param node_offset: How much to offset node values contained in file
    :type node_offset: int
    :param parent_fpath: Path to prepend to `fname`
    :type parent_fpath: str
    :return: Graph defined in provided file
    :rtype: networkx.OrderedGraph === CAMBIATO con network.DiGraph
    """

    fpath = os.path.join(parent_fpath, fname)

    print(f'Building graph from contents of file: {fpath}')
    with open(fpath, 'r') as f:
        content = f.read().strip()

    # Identify where problem definition starts.
    # All lines prior to this are assumed to be miscellaneous descriptions of file contents
    # which start with "c = p".
    start_idx = [idx for idx, line in enumerate(content.split('\n')) if line.startswith('p')][0]
    lines = content.split('\n')[start_idx:]  # skip comment line(s)
    edges = [parse_line(line, node_offset) for line in lines[1:] if len(line) > 0]

    nx_temp = nx.from_edgelist(edges)

    nx_graph = nx.Graph()    #QUESTO É TUTTO, se metto DiGraph é grafo DIRETTO, sennó Undirect concettualmente é piu giusto
    nx_graph.add_nodes_from(sorted(nx_temp.nodes()))    #qua mi sa leva i link doppi, ma quando creo torch tensor non lo fa
    nx_graph.add_edges_from(nx_temp.edges)

    return nx_graph

# %% [markdown]
# # Step 1 - Set hyperparameters
#
# We provide a default set of model hypers. Feel free to modify these as desired.
#
# We also include general parameters such as tolerance and patience for early stopping, the layer aggregation specification (`layer_agg_type`) for GraphSAGE, and some tracking of problem definition (problem name, chromatic number).

# %%
# Specify the problem instance to solve and where to find the dataset(s) here:

problem_file = 'queen7_7.col'     #tipo prima era 'queen5_5.col'    #RICORDA DI CAMBIARE IL FILE IN CUI METTI IL BEST MODELLO

save_model_path = 'SAGE_best_model_coloring_7X7'   #se cambio problem file, devo cambare anche il nome del file dove salvo il modello addestrato

input_parent = './data/input/COLOR/instances'

# %%
# Sample hyperparameters
hypers = {
        'model': 'SAGEConv',   # set either with GNN. It cannot take other input (lo metto dopo)      #sono quelli di GCN conv
        'dim_embedding': 67,
        'dropout': 0.2339,
        'learning_rate': 0.02175,      #0.02988  per 5x5     #prova con 0.01
        'hidden_dim': 12,            #prima 32
        'seed': SEED_VALUE
    }


# Default meta parameters
solver_hypers = {
    'tolerance': 1e-3,           # Loss must change by more than tolerance, or add towards patience count
    'number_epochs': int(5e4),   # Max number training steps   #non lo cambio da qui
    'patience': 500,             # Number early stopping triggers before breaking loop #non lo cambio da qui
    'graph_file': problem_file,  # Which problem is being solved
    'layer_agg_type': 'mean',    # How aggregate neighbors sampled within graphSAGE
    'number_classes': chromatic_numbers[problem_file]
}

# Combine into a single set
hypers.update(solver_hypers)

# %% [markdown]
# # Step 2 - Load in problem and create graph
#
# Load in problem definition from specified path. Variables `input_parent` and `problem_file` should be defined appropriately in cell 3.

# %%
from torch_geometric.utils import from_networkx

# %%
# Establish full input location
input_fpath = os.path.join(input_parent, problem_file)

# Load in graph
nx_graph = build_graph_from_color_file(input_fpath, node_offset=-1, parent_fpath='')

# Get DGL graph from networkx graph
# Ensure relevant objects are placed onto proper torch device
torchgeom_graph = from_networkx(nx_graph)
torchgeom_graph = torchgeom_graph.to(TORCH_DEVICE)
# Out:
# Building graph from contents of file: ./data/input/COLOR/instances/queen7_7.col

# %%
print('torchgeom_graf=',torchgeom_graph)    #oh ok
print(torchgeom_graph.num_nodes)
print(torchgeom_graph.edge_index)
# Out:
# torchgeom_graf= Data(edge_index=[2, 952], num_nodes=49)
# 49
# tensor([[ 0,  0,  0,  ..., 48, 48, 48],
#         [ 8, 16, 24,  ..., 45, 46, 47]])

# %%
# Visualize graph
pos = nx.kamada_kawai_layout(nx_graph)
nx.draw(nx_graph, pos, with_labels=True, node_color=[[.7, .7, .7]])

# %%
#creo classe della mia GNN


class GraphSAGE(nn.Module):
    """
    Basic GraphConv-based GNN class object. Constructs the model architecture upon
    initialization. Defines a forward step to include relevant parameters - in this
    case, just dropout.
    """
                            #self é la sua roba, g é torchgeom_graph
    def __init__(self, g, in_feats, hidden_size, num_classes, dropout):   #le in_feats diventano dim_embedding, hidden size e num_classes é da hypers
        """
        Initialize the model object. Establishes model architecture and relevant hypers (`dropout`, `num_classes`, `agg_type`)

        :param g: Input graph object
        :type g: Data of torch geometric
        :param in_feats: Size (number of nodes) of input layer
        :type in_feats: int
        :param hidden_size: Size of hidden layer
        :type hidden_size: int
        :param num_classes: Size of output layer (one node per class)
        :type num_classes: int
        :param dropout: Dropout fraction, between two convolutional layers
        :type dropout: float
        """

        super(GraphSAGE, self).__init__()
        self.g = g
        self.conv1 = SAGEConv(in_feats, hidden_size)
        self.relu=nn.ReLU()
        self.dropout = nn.Dropout(p=dropout)
        self.conv2 = SAGEConv(hidden_size, num_classes)

    def forward(self, g):
        """
        Define forward step of netowrk. In this example, pass inputs through convolution, apply relu
        and dropout, then pass through second convolution.

        :param features: Input node representations
        :type features: torch.tensor
        :return: Final layer representation, pre-activation (i.e. class logits)
        :rtype: torch.tensor"""

        x, edge_index = g.x, g.edge_index
        x = self.conv1(x, edge_index)
        x = self.relu(x)
        x = self.dropout(x)
        x = self.conv2(x, edge_index)
        return x

# %%
print(torchgeom_graph)
# Out:
# Data(edge_index=[2, 952], num_nodes=49)

# %%
dim_embedding = hypers['dim_embedding']
hidden_dim = hypers['hidden_dim']
dropout = hypers['dropout']
number_classes = hypers['number_classes']
agg_type = hypers['layer_agg_type'] or 'mean'
model=hypers['model']
print(model)
# Out:
# SAGEConv

# %%
print(hidden_dim)
# Out:
# 12

# %%
embed = nn.Embedding(torchgeom_graph.num_nodes, dim_embedding)    #sto creando matrice  #sarebbero le in_feat ==  dim_embedding, creo #copie di valori dei nodi pari a dim_embedding
embed = embed.type(TORCH_DTYPE).to(TORCH_DEVICE)
print(embed)
# Out:
# Embedding(49, 67)

# %%
data = Data(x=embed.weight, edge_index=torchgeom_graph.edge_index)
print(data.x.shape)
print(data.edge_index.shape)   #OK
# Out:
# torch.Size([49, 67])
# torch.Size([2, 952])

# %%
# instantiate the GNN
print(f'Building {model} model...')
if model=='SAGEConv':
  net = GraphSAGE(data, dim_embedding, hidden_dim, number_classes, dropout)      #sarebbe la mia classe che devo definire (fatto sopra)
  #net = GraphSAGE(in_channels=dim_embedding, hidden_channels=dim_embedding, out_channels=num_classes)
elif model == 'GNN':
  #net = GCN(Conv)
  print('ci va l altra')
print(net)
# Out:
# Building SAGEConv model...
# GraphSAGE(
#   (conv1): SAGEConv(67, 12, aggr=mean)
#   (relu): ReLU()
#   (dropout): Dropout(p=0.2339, inplace=False)
#   (conv2): SAGEConv(12, 7, aggr=mean)
# )

# %%
# Retrieve known optimizer hypers
opt_hypers = {
    'lr': hypers.get('learning_rate', None)
}

# Get adjacency matrix for use in calculations
adj_ = get_adjacency_matrix(nx_graph, TORCH_DEVICE, TORCH_DTYPE)

# See minimal_utils.py for description. Constructs GNN and optimizer objects from given hypers.
# Initializes embedding layer to use as initial model input
#net, embed, optimizer gia def

# %%
# set up Adam optimizer
params = chain(net.parameters(), embed.parameters())

print('Building ADAM-W optimizer...')
optimizer = torch.optim.AdamW(params, **opt_hypers, weight_decay=1e-2)            #weight_decay = decadimento esponenziale che contiene overfitting
#scheduler= torch.optim.lr_scheduler.StepLR(optimizer,step_size=100000,gamma=1.5)    #AGGIUNTA IL 18/10 #step_size, ogni quante epoche il lr diminuisce del 10%(gamma=0.1)
#scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, 'min', patience=500)


print(optimizer)
# Out:
# Building ADAM-W optimizer...
# AdamW (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     lr: 0.02175
#     maximize: False
#     weight_decay: 0.01
# )

# %%
# helper function for graph-coloring loss
def loss_func_mod(probs, adj_tensor):
    """
    Function to compute cost value based on soft assignments (probabilities)

    :param probs: Probability vector, of each node belonging to each class
    :type probs: torch.tensor
    :param adj_tensor: Adjacency matrix, containing internode weights
    :type adj_tensor: torch.tensor
    :return: Loss, given the current soft assignments (probabilities)
    :rtype: float
    """

    # Multiply probability vectors, then filter via elementwise application of adjacency matrix.
    #  Divide by 2 to adjust for symmetry about the diagonal
    loss_ = torch.mul(adj_tensor, (probs @ probs.T)).sum() / 2

    return loss_      #sarebbe la mia energia di potts

# helper function for custom loss according to Q matrix
def loss_func_color_hard(coloring, nx_graph):
    """
    Function to compute cost value based on color vector (0, 2, 1, 4, 1, ...)

    :param coloring: Vector of class assignments (colors)
    :type coloring: torch.tensor
    :param nx_graph: Graph to evaluate classifications on
    :type nx_graph: networkx.OrderedGraph  --> da me cambiato con DiGraph
    :return: Cost of provided class assignments
    :rtype: torch.tensor
    """

    cost_ = 0
    for (u, v) in nx_graph.edges:
        cost_ += 1*(coloring[u] == coloring[v])*(u != v)     #1 if the two nodes have the same color and are not the same node

    return cost_

# %%
# Ensure RNG seeds are reset each training run
seed=hypers['seed']
print(f'Start training(): Setting seed to {seed}')
#seed=1
set_seed(seed)
number_epochs=int(1e5)    #forse dovrei mettere meno
patience=500
tolerance=1e-3


# Tracking
best_cost = torch.tensor(float('Inf'))  # high initialization
best_loss = torch.tensor(float('Inf'))
best_coloring = None

# Early stopping to allow NN to train to near-completion
prev_loss = 1.  # initial loss value (arbitrary)
cnt = 0  # track number times early stopping is triggered
#count_stessicolori=0


#metto conto del tempo
t_start = time()
loss_vector_story=[]
hard_cost_vector_story=[]

count_stessicolori=0



# Training logic
for epoch in range(number_epochs):
    # get soft prob assignments
    logits = net(data)       #rispetto a prima net mi prende tutto il formato data

    # apply softmax for normalization
    probs = F.softmax(logits, dim=1)       #qua dovrebbe normalizzare
    #print('probs=',probs)   #print(probs.shape)========esce 25x5 (sarebbero le 5 prob dei 5 colori per ogni nodo, poi devo prendere quella maggiore)

    # get cost value with POTTS cost function
    loss = loss_func_mod(probs, adj_)              #calcolo la loss con modello potts

    # get cost based on current hard class assignments
    # update cost if applicable
    coloring = torch.argmax(probs, dim=1)                               #questo é effettivamente il vettore dei colori di questa epoca (con 25 elementi che sono numeri da 0 a 4)
    cost_hard = loss_func_color_hard(coloring, nx_graph)           #nodi diversi ma collegati e dello stesso colore

    if cost_hard < best_cost:           #best_cost= il miglior cost_hard    #best_coloring=il coloring col miglior cost_hard
        best_loss = loss
        best_cost = cost_hard     #sarebbe sbaglio 'discreto'
        best_coloring = coloring
        save_model(net,save_model_path, best_cost, best_loss, epoch)
        #torch.save(net.state_dict(), 'SAGE_best_model_coloring_5X5.pth')                    #aggiunto stasera
        #print(f'Model saved with best_cost: {best_cost:.4f}  and best_loss(soft loss): {best_loss:.4f} at the epoch: {epoch}')             #aggiunto stasera

    # Early stopping check
    # If loss increases or change in loss is too small, trigger
    if (abs(loss - prev_loss) <= tolerance) | ((loss - prev_loss) > 0):
        cnt += 1
    else:
        cnt = 0

    #if (best_cost == cost_hard):
    #    count_stessicolori+=1
    #else:
    #    count_stessicolori=0

    # update loss tracking
    prev_loss = loss

    loss_vector_story.append(loss.item())               #mi dovrebbe dare la loss nelle epoche (ogni 1000)
    hard_cost_vector_story.append(cost_hard.item())

    if cnt >= patience:
        print(f'Stopping early on epoch {epoch}. Patience count: {cnt}')
        break

    #if count_stessicolori >= patience:
    #    optimizer = torch.optim.AdamW(params, **opt_hypers, weight_decay=1e-1)
    #    print()

    # run optimization with backpropagation
    optimizer.zero_grad()  # clear gradient for step
    loss.backward()  # calculate gradient through compute graph
    optimizer.step()  # take step, update weights
    #scheduler.step()

    # tracking: print intermediate loss at regular interval
    if epoch % 1000 == 0:
        print('Epoch %d | Soft Loss: %.5f' % (epoch, loss.item()))
        print('Epoch %d | Discrete Cost: %.5f' % (epoch, cost_hard.item()))

# Print final loss
print('Epoch %d | Final loss: %.5f' % (epoch, loss.item()))
print('Epoch %d | Lowest discrete cost: %.5f' % (epoch, best_cost))

# Final coloring
final_loss = loss
final_coloring = torch.argmax(probs, 1)
print(f'Final coloring: {final_coloring}, soft loss: {final_loss}')
print(f'Best coloring: {best_coloring}, soft loss: {best_loss}')

#conto finale del tempo
runtime_gnn = round(time() - t_start, 4)
# report results
print(f'GNN runtime: {runtime_gnn}s')
# Out:
# Start training(): Setting seed to 0
# Model saved with best_cost: 99.0000  and best_loss(soft loss): 70.7668 at the epoch: 0
# Epoch 0 | Soft Loss: 70.76677
# Epoch 0 | Discrete Cost: 99.00000
# Model saved with best_cost: 86.0000  and best_loss(soft loss): 68.5233 at the epoch: 2
# Model saved with best_cost: 82.0000  and best_loss(soft loss): 67.8477 at the epoch: 7
# Model saved with best_cost: 76.0000  and best_loss(soft loss): 67.5349 at the epoch: 8
# Model saved with best_cost: 75.0000  and best_loss(soft loss): 67.6201 at the epoch: 9
# Model saved with best_cost: 74.0000  and best_loss(soft loss): 67.2694 at the epoch: 10
# Model saved with best_cost: 71.0000  and best_loss(soft loss): 66.3466 at the epoch: 12
# Model saved with best_cost: 66.0000  and best_loss(soft loss): 66.2302 at the epoch: 13
# Model saved with best_cost: 59.0000  and best_loss(soft loss): 62.8633 at the epoch: 16
# Model saved with best_cost: 42.0000  and best_loss(soft loss): 60.7927 at the epoch: 17
# Model saved with best_cost: 41.0000  and best_loss(soft loss): 53.0743 at the epoch: 20
# Model saved with best_cost: 38.0000  and best_loss(soft loss): 45.8473 at the epoch: 24
# Model saved with best_cost: 32.0000  and best_loss(soft loss): 34.7379 at the epoch: 28
# Model saved with best_cost: 28.0000  and best_loss(soft loss): 35.2294 at the epoch: 30
# Model saved with best_cost: 27.0000  and best_loss(soft loss): 27.4211 at the epoch: 36
# Model saved with best_cost: 26.0000  and best_loss(soft loss): 27.3785 at the epoch: 38
# Model saved with best_cost: 25.0000  and best_loss(soft loss): 26.0318 at the epoch: 45
# Model saved with best_cost: 23.0000  and best_loss(soft loss): 23.4317 at the epoch: 55
# Model saved with best_cost: 22.0000  and best_loss(soft loss): 22.2715 at the epoch: 76
# Model saved with best_cost: 21.0000  and best_loss(soft loss): 21.5594 at the epoch: 126
# Model saved with best_cost: 20.0000  and best_loss(soft loss): 20.0400 at the epoch: 285
# Model saved with best_cost: 19.0000  and best_loss(soft loss): 19.4388 at the epoch: 296
# Model saved with best_cost: 18.0000  and best_loss(soft loss): 18.0220 at the epoch: 403
# Model saved with best_cost: 17.0000  and best_loss(soft loss): 17.5867 at the epoch: 418
# Epoch 1000 | Soft Loss: 18.00852
# Epoch 1000 | Discrete Cost: 18.00000
# Epoch 2000 | Soft Loss: 18.00000
# Epoch 2000 | Discrete Cost: 18.00000
# Epoch 3000 | Soft Loss: 20.97754
# Epoch 3000 | Discrete Cost: 21.00000
# Epoch 4000 | Soft Loss: 18.00000
# Epoch 4000 | Discrete Cost: 18.00000
# Epoch 5000 | Soft Loss: 20.00000
# Epoch 5000 | Discrete Cost: 20.00000
# Model saved with best_cost: 16.0000  and best_loss(soft loss): 16.0000 at the epoch: 5751
# Epoch 6000 | Soft Loss: 17.00000
# Epoch 6000 | Discrete Cost: 17.00000
# Epoch 7000 | Soft Loss: 18.00012
# Epoch 7000 | Discrete Cost: 18.00000
# Model saved with best_cost: 15.0000  and best_loss(soft loss): 15.0000 at the epoch: 7090
# Epoch 8000 | Soft Loss: 15.00000
# Epoch 8000 | Discrete Cost: 15.00000
# Model saved with best_cost: 13.0000  and best_loss(soft loss): 13.0000 at the epoch: 8169
# Model saved with best_cost: 12.0000  and best_loss(soft loss): 12.0003 at the epoch: 8772
# Epoch 9000 | Soft Loss: 13.00000
# Epoch 9000 | Discrete Cost: 13.00000
# Model saved with best_cost: 11.0000  and best_loss(soft loss): 11.8167 at the epoch: 9720
# Epoch 10000 | Soft Loss: 14.00562
# Epoch 10000 | Discrete Cost: 14.00000
# Epoch 11000 | Soft Loss: 12.93328
# Epoch 11000 | Discrete Cost: 13.00000
# Model saved with best_cost: 10.0000  and best_loss(soft loss): 10.0259 at the epoch: 11179
# Epoch 12000 | Soft Loss: 12.00036
# Epoch 12000 | Discrete Cost: 12.00000
# Model saved with best_cost: 9.0000  and best_loss(soft loss): 9.0000 at the epoch: 12413
# Epoch 13000 | Soft Loss: 9.84448
# Epoch 13000 | Discrete Cost: 10.00000
# Epoch 14000 | Soft Loss: 13.96604
# Epoch 14000 | Discrete Cost: 14.00000
# Epoch 15000 | Soft Loss: 13.00000
# Epoch 15000 | Discrete Cost: 13.00000
# Epoch 16000 | Soft Loss: 11.00063
# Epoch 16000 | Discrete Cost: 11.00000
# Epoch 17000 | Soft Loss: 9.00000
# Epoch 17000 | Discrete Cost: 9.00000
# Epoch 18000 | Soft Loss: 9.16226
# Epoch 18000 | Discrete Cost: 9.00000
# Epoch 19000 | Soft Loss: 9.00000
# Epoch 19000 | Discrete Cost: 9.00000
# Epoch 20000 | Soft Loss: 13.29413
# Epoch 20000 | Discrete Cost: 13.00000
# Epoch 21000 | Soft Loss: 9.00000
# Epoch 21000 | Discrete Cost: 9.00000
# Epoch 22000 | Soft Loss: 9.00000
# Epoch 22000 | Discrete Cost: 9.00000
# Epoch 23000 | Soft Loss: 10.79066
# Epoch 23000 | Discrete Cost: 11.00000
# Epoch 24000 | Soft Loss: 9.81309
# Epoch 24000 | Discrete Cost: 9.00000
# Epoch 25000 | Soft Loss: 9.19600
# Epoch 25000 | Discrete Cost: 9.00000
# Epoch 26000 | Soft Loss: 9.00000
# Epoch 26000 | Discrete Cost: 9.00000
# Epoch 27000 | Soft Loss: 9.00000
# Epoch 27000 | Discrete Cost: 9.00000
# Epoch 28000 | Soft Loss: 9.00000
# Epoch 28000 | Discrete Cost: 9.00000
# Epoch 29000 | Soft Loss: 14.00001
# Epoch 29000 | Discrete Cost: 14.00000
# Epoch 30000 | Soft Loss: 9.00000
# Epoch 30000 | Discrete Cost: 9.00000
# Epoch 31000 | Soft Loss: 9.00000
# Epoch 31000 | Discrete Cost: 9.00000
# Epoch 32000 | Soft Loss: 9.00000
# Epoch 32000 | Discrete Cost: 9.00000
# Epoch 33000 | Soft Loss: 9.00075
# Epoch 33000 | Discrete Cost: 9.00000
# Epoch 34000 | Soft Loss: 9.00000
# Epoch 34000 | Discrete Cost: 9.00000
# Epoch 35000 | Soft Loss: 9.00000
# Epoch 35000 | Discrete Cost: 9.00000
# Epoch 36000 | Soft Loss: 10.22078
# Epoch 36000 | Discrete Cost: 11.00000
# Epoch 37000 | Soft Loss: 9.00000
# Epoch 37000 | Discrete Cost: 9.00000
# Epoch 38000 | Soft Loss: 9.00000
# Epoch 38000 | Discrete Cost: 9.00000
# Epoch 39000 | Soft Loss: 9.00387
# Epoch 39000 | Discrete Cost: 9.00000
# Epoch 40000 | Soft Loss: 9.00000
# Epoch 40000 | Discrete Cost: 9.00000
# Epoch 41000 | Soft Loss: 9.00000
# Epoch 41000 | Discrete Cost: 9.00000
# Epoch 42000 | Soft Loss: 9.00000
# Epoch 42000 | Discrete Cost: 9.00000
# Epoch 43000 | Soft Loss: 9.00000
# Epoch 43000 | Discrete Cost: 9.00000
# Epoch 44000 | Soft Loss: 9.00001
# Epoch 44000 | Discrete Cost: 9.00000
# Epoch 45000 | Soft Loss: 14.00009
# Epoch 45000 | Discrete Cost: 14.00000
# Epoch 46000 | Soft Loss: 9.00000
# Epoch 46000 | Discrete Cost: 9.00000
# Epoch 47000 | Soft Loss: 10.98693
# Epoch 47000 | Discrete Cost: 12.00000
# Epoch 48000 | Soft Loss: 9.00000
# Epoch 48000 | Discrete Cost: 9.00000
# Epoch 49000 | Soft Loss: 9.00000
# Epoch 49000 | Discrete Cost: 9.00000
# Epoch 50000 | Soft Loss: 9.00000
# Epoch 50000 | Discrete Cost: 9.00000
# Epoch 51000 | Soft Loss: 9.05864
# Epoch 51000 | Discrete Cost: 9.00000
# Epoch 52000 | Soft Loss: 12.01086
# Epoch 52000 | Discrete Cost: 12.00000
# Epoch 53000 | Soft Loss: 9.00000
# Epoch 53000 | Discrete Cost: 9.00000
# Epoch 54000 | Soft Loss: 9.05966
# Epoch 54000 | Discrete Cost: 9.00000
# Epoch 55000 | Soft Loss: 12.00000
# Epoch 55000 | Discrete Cost: 12.00000
# Epoch 56000 | Soft Loss: 9.00000
# Epoch 56000 | Discrete Cost: 9.00000
# Epoch 57000 | Soft Loss: 10.00000
# Epoch 57000 | Discrete Cost: 10.00000
# Epoch 58000 | Soft Loss: 9.00000
# Epoch 58000 | Discrete Cost: 9.00000
# Epoch 59000 | Soft Loss: 11.99991
# Epoch 59000 | Discrete Cost: 12.00000
# Epoch 60000 | Soft Loss: 10.24323
# Epoch 60000 | Discrete Cost: 11.00000
# Epoch 61000 | Soft Loss: 9.00000
# Epoch 61000 | Discrete Cost: 9.00000
# Epoch 62000 | Soft Loss: 9.05007
# Epoch 62000 | Discrete Cost: 9.00000
# Epoch 63000 | Soft Loss: 9.00000
# Epoch 63000 | Discrete Cost: 9.00000
# Epoch 64000 | Soft Loss: 10.99990
# Epoch 64000 | Discrete Cost: 11.00000
# Epoch 65000 | Soft Loss: 10.33509
# Epoch 65000 | Discrete Cost: 11.00000
# Epoch 66000 | Soft Loss: 11.46369
# Epoch 66000 | Discrete Cost: 11.00000
# Epoch 67000 | Soft Loss: 9.00000
# Epoch 67000 | Discrete Cost: 9.00000
# Epoch 68000 | Soft Loss: 9.00000
# Epoch 68000 | Discrete Cost: 9.00000
# Epoch 69000 | Soft Loss: 9.00000
# Epoch 69000 | Discrete Cost: 9.00000
# Epoch 70000 | Soft Loss: 9.00000
# Epoch 70000 | Discrete Cost: 9.00000
# Epoch 71000 | Soft Loss: 9.00005
# Epoch 71000 | Discrete Cost: 9.00000
# Epoch 72000 | Soft Loss: 9.00002
# Epoch 72000 | Discrete Cost: 9.00000
# Epoch 73000 | Soft Loss: 9.00000
# Epoch 73000 | Discrete Cost: 9.00000
# Epoch 74000 | Soft Loss: 9.00962
# Epoch 74000 | Discrete Cost: 9.00000
# Epoch 75000 | Soft Loss: 9.00000
# Epoch 75000 | Discrete Cost: 9.00000
# Epoch 76000 | Soft Loss: 9.00000
# Epoch 76000 | Discrete Cost: 9.00000
# Epoch 77000 | Soft Loss: 9.00000
# Epoch 77000 | Discrete Cost: 9.00000
# Epoch 78000 | Soft Loss: 9.00000
# Epoch 78000 | Discrete Cost: 9.00000
# Epoch 79000 | Soft Loss: 9.00000
# Epoch 79000 | Discrete Cost: 9.00000
# Epoch 80000 | Soft Loss: 12.00000
# Epoch 80000 | Discrete Cost: 12.00000
# Epoch 81000 | Soft Loss: 9.00000
# Epoch 81000 | Discrete Cost: 9.00000
# Epoch 82000 | Soft Loss: 9.00000
# Epoch 82000 | Discrete Cost: 9.00000
# Epoch 83000 | Soft Loss: 9.00000
# Epoch 83000 | Discrete Cost: 9.00000
# Epoch 84000 | Soft Loss: 13.00000
# Epoch 84000 | Discrete Cost: 13.00000
# Epoch 85000 | Soft Loss: 10.99999
# Epoch 85000 | Discrete Cost: 11.00000
# Epoch 86000 | Soft Loss: 9.00000
# Epoch 86000 | Discrete Cost: 9.00000
# Epoch 87000 | Soft Loss: 9.00000
# Epoch 87000 | Discrete Cost: 9.00000
# Epoch 88000 | Soft Loss: 9.00000
# Epoch 88000 | Discrete Cost: 9.00000
# Epoch 89000 | Soft Loss: 10.00000
# Epoch 89000 | Discrete Cost: 10.00000
# Epoch 90000 | Soft Loss: 13.99999
# Epoch 90000 | Discrete Cost: 14.00000
# Epoch 91000 | Soft Loss: 9.02759
# Epoch 91000 | Discrete Cost: 9.00000
# Epoch 92000 | Soft Loss: 12.00000
# Epoch 92000 | Discrete Cost: 12.00000
# Epoch 93000 | Soft Loss: 14.00000
# Epoch 93000 | Discrete Cost: 14.00000
# Epoch 94000 | Soft Loss: 9.00000
# Epoch 94000 | Discrete Cost: 9.00000
# Epoch 95000 | Soft Loss: 9.00000
# Epoch 95000 | Discrete Cost: 9.00000
# Epoch 96000 | Soft Loss: 10.00000
# Epoch 96000 | Discrete Cost: 10.00000
# Epoch 97000 | Soft Loss: 9.00000
# Epoch 97000 | Discrete Cost: 9.00000
# Epoch 98000 | Soft Loss: 9.00000
# Epoch 98000 | Discrete Cost: 9.00000
# Epoch 99000 | Soft Loss: 11.26302
# Epoch 99000 | Discrete Cost: 12.00000
# Epoch 99999 | Final loss: 9.99999
# Epoch 99999 | Lowest discrete cost: 9.00000
# Final coloring: tensor([1, 6, 2, 4, 5, 0, 1, 0, 5, 1, 3, 2, 6, 4, 4, 2, 6, 5, 0, 1, 3, 6, 1, 4,
#         2, 3, 5, 6, 2, 3, 3, 6, 4, 0, 5, 6, 4, 5, 0, 1, 3, 2, 5, 0, 1, 4, 6, 3,
#         0]), soft loss: 9.999990463256836
# Best coloring: tensor([3, 6, 2, 4, 5, 0, 1, 0, 5, 1, 3, 2, 6, 4, 4, 2, 6, 5, 0, 1, 3, 0, 1, 4,
#         2, 3, 5, 6, 2, 1, 3, 6, 4, 4, 5, 6, 4, 5, 0, 1, 1, 2, 5, 0, 1, 2, 6, 3,
#         0]), soft loss: 9.0
# GNN runtime: 1826.0604s

# %%
loss_vector_story_array=np.array(loss_vector_story)
hard_cost_vector_story_array= np.array(hard_cost_vector_story)

print(loss_vector_story_array.shape)
# Out:
# (100000,)

# %%
# Traccio il grafico della loss
from matplotlib import pyplot as plt
import math
#loss_vector_story_array= np.array(loss_vector_story)

plt.figure(figsize=(10, 5))
plt.plot(range((loss_vector_story_array.shape[0])), loss_vector_story_array, label='Loss')
plt.title('Loss durante l\'addestramento con lr:0.0001 e weight decay 0.01')
plt.xlabel('Epoche')
plt.ylabel('Loss')
plt.yticks(range(0, math.floor(max(loss_vector_story)) + 1, 10))
plt.legend()
plt.grid()
plt.show()

# %%
# Traccia il grafico della loss
from matplotlib import pyplot as plt

plt.figure(figsize=(10, 5))
plt.plot(range((hard_cost_vector_story_array.shape[0])), hard_cost_vector_story, label='Loss')
plt.title('Costo discreto durante l\'addestramento con lr:0.0001 e weight decay 0.01')
plt.xlabel('Epoche')
plt.ylabel('Costo discreto')
plt.yticks(range(0, max(hard_cost_vector_story) + 10, 10))
plt.legend()
plt.grid()
plt.show()

# %%
# Visualize result
color_dict = {0:'orange', 1:'lightblue', 2:'purple', 3:'red', 4:'lightgreen'}
color_map = np.vectorize(color_dict.get)(best_coloring.cpu())
nx.draw(nx_graph, pos, with_labels=False, node_color=color_map)

# %% [markdown]
# **Esempio con uno**

# %%
logits = net(data)       #rispetto a prima net mi prende tutto il formato data

# apply softmax for normalization
probs = F.softmax(logits, dim=1)       #qua dovrebbe normalizzare
    #print('probs=',probs)   #print(probs.shape)========esce 25x5 (sarebbero le 5 prob dei 5 colori per ogni nodo, poi devo prendere quella maggiore)

    # get cost value with POTTS cost function
loss = loss_func_mod(probs, adj_)              #calcolo la loss con modello potts

    # get cost based on current hard class assignments
    # update cost if applicable
coloring = torch.argmax(probs, dim=1)                               #questo é effettivamente il vettore dei colori di questa epoca (con 25 elementi che sono numeri da 0 a 4)
cost_hard = loss_func_color_hard(coloring, nx_graph)

# %%
# Visualize result
color_dict = {0:'orange', 1:'lightblue', 2:'purple', 3:'red', 4:'lightgreen'}
color_map = np.vectorize(color_dict.get)(best_coloring.cpu())
nx.draw(nx_graph, pos, with_labels=False, node_color=color_map)
